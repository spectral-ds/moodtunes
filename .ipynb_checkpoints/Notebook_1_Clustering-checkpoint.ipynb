# %% [markdown]
# # MoodTunes — Music Mood Classifier & Playlist Generator
# ### Notebook 1: K-Means Clustering
# **Term Project | B.Sc. Data Science & AI | IIT Guwahati**
# **Sudipta Tripura | Roll: 23035010558**
#
# ---
#
# For this project I wanted to build something that groups songs by how they feel rather than just their genre. The idea is to use Spotify's pre-computed audio features — things like energy, tempo, and valence — to automatically cluster songs into mood categories using K-Means.
#
# No manual labelling needed. The algorithm figures out the groups on its own.
#
# **Dataset:** Spotify Tracks Dataset from Kaggle — around 114,000 songs

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

warnings.filterwarnings('ignore')
print("imports done")
# Out:
# imports done

# %% [markdown]
# ## 2. Load the Dataset
#
# Loading the CSV and doing a quick look at what we have.

# %%
df = pd.read_csv('data/dataset.csv')

print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print("Missing values:")
print(df.isnull().sum())
df.head()
# Out:
# Shape: (114000, 21)
# Columns: ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']
# Missing values:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# ...

# %% [markdown]
# ## 3. Cleaning
#
# Three quick steps — drop the useless index column, remove the one row with missing values, and remove duplicate tracks (the same song appears in multiple genres in this dataset so we keep only one copy per track ID).

# %%
# remove auto-generated index
df = df.drop(columns=['Unnamed: 0'])

# drop the 1 missing row
df = df.dropna()

# remove duplicate track IDs
df = df.drop_duplicates(subset=['track_id'])

print(f"After cleaning: {df.shape[0]} songs, {df.shape[1]} columns")
# Out:
# After cleaning: 89740 songs, 20 columns

# %% [markdown]
# ## 4. Quick Data Exploration
#
# Before jumping into clustering I want to see the popularity distribution and which genres have the most songs.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# popularity distribution
axes[0].hist(df['popularity'], bins=50, color='steelblue', edgecolor='white', alpha=0.8)
axes[0].axvline(df['popularity'].mean(), color='red', linestyle='--',
                label=f"mean = {df['popularity'].mean():.1f}")
axes[0].set_title('Popularity Distribution')
axes[0].set_xlabel('Popularity Score')
axes[0].set_ylabel('Count')
axes[0].legend()

# top genres
top_genres = df['track_genre'].value_counts().head(12)
axes[1].barh(top_genres.index[::-1], top_genres.values[::-1], color='coral', alpha=0.8)
axes[1].set_title('Top 12 Genres by Song Count')
axes[1].set_xlabel('Songs')

plt.tight_layout()
plt.savefig('dataset_overview.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Choosing Features for Mood Clustering
#
# Not all 21 columns are useful here. I picked 6 features that I think capture mood the best:
#
# - **valence** — how happy or sad a song sounds (0 = sad, 1 = happy)
# - **energy** — how intense or calm it feels
# - **danceability** — how easy it is to dance to
# - **acousticness** — acoustic vs electronic
# - **tempo** — speed in BPM
# - **loudness** — overall volume in dB
#
# I left out things like key, mode, duration, and explicit since those don't directly relate to mood.

# %%
MOOD_FEATURES = [
    'valence',
    'energy',
    'danceability',
    'acousticness',
    'tempo',
    'loudness'
]

# quick summary of each feature
print(f"{'Feature':<15} {'Min':>8} {'Max':>8} {'Mean':>8}")
print("-" * 42)
for feat in MOOD_FEATURES:
    print(f"{feat:<15} {df[feat].min():>8.2f} {df[feat].max():>8.2f} {df[feat].mean():>8.2f}")
# Out:
# Feature              Min      Max     Mean
# ------------------------------------------
# valence             0.00     0.99     0.47
# energy              0.00     1.00     0.63
# danceability        0.00     0.98     0.56
# acousticness        0.00     1.00     0.33
# tempo               0.00   243.37   122.06
# loudness          -49.53     4.53    -8.50

# %% [markdown]
# ## 6. Feature Distributions
#
# Plotting the distribution of each feature just to understand the data before clustering.

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Mood Feature Distributions', fontsize=14, fontweight='bold')

colors = ['#4ECDC4', '#FF6B6B', '#45B7D1', '#96CEB4', '#FFEAA7', '#DDA0DD']

for i, (feat, color) in enumerate(zip(MOOD_FEATURES, colors)):
    row, col = i // 3, i % 3
    axes[row, col].hist(df[feat], bins=50, color=color, edgecolor='white', alpha=0.85)
    axes[row, col].axvline(df[feat].mean(), color='red', linestyle='--', linewidth=1.2,
                           label=f"mean={df[feat].mean():.2f}")
    axes[row, col].set_title(feat)
    axes[row, col].set_xlabel('value')
    axes[row, col].set_ylabel('count')
    axes[row, col].legend(fontsize=8)

plt.tight_layout()
plt.savefig('mood_features_distribution.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. Correlation Between Features
#
# Just checking how the features relate to each other. Loudness and energy are highly correlated which makes sense — louder songs usually feel more intense.

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(
    df[MOOD_FEATURES].corr(),
    annot=True, fmt='.2f',
    cmap='RdYlGn', center=0,
    square=True, linewidths=0.5
)
plt.title('Feature Correlation Matrix', fontweight='bold')
plt.tight_layout()
plt.savefig('feature_correlation.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Scaling the Features
#
# K-Means measures distance between songs. If I leave the features at their original scale, tempo (0–250) would dominate over valence (0–1) just because it has larger numbers.
#
# StandardScaler fixes this by converting everything to mean=0, std=1.

# %%
scaler = StandardScaler()
features_scaled = scaler.fit_transform(df[MOOD_FEATURES])

print(f"Scaled shape: {features_scaled.shape}")
print(f"Mean after scaling: {features_scaled.mean():.4f}")
print(f"Std after scaling:  {features_scaled.std():.4f}")
# Out:
# Scaled shape: (89740, 6)
# Mean after scaling: -0.0000
# Std after scaling:  1.0000

# %% [markdown]
# ## 9. Elbow Method — How Many Clusters?
#
# I need to tell K-Means how many clusters to find. The Elbow Method helps with this — I run K-Means for k=2 to 10 and plot the inertia. The point where the curve stops dropping sharply is a good choice for k.
#
# I'm expecting k=5 to work well since I want 5 moods: Happy, Sad, Energetic, Calm, Angry.

# %%
inertias = []
k_range = range(2, 11)

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(features_scaled)
    inertias.append(km.inertia_)
    print(f"k={k}: inertia={km.inertia_:,.0f}")

plt.figure(figsize=(9, 5))
plt.plot(k_range, inertias, 'o-', color='steelblue', linewidth=2, markersize=8,
         markerfacecolor='white', markeredgewidth=2)
plt.axvline(x=5, color='red', linestyle='--', alpha=0.7, label='k=5 selected')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.xticks(k_range)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('elbow_plot.png', dpi=120, bbox_inches='tight')
plt.show()
# Out:
# k=2: inertia=370,043
# k=3: inertia=303,969
# k=4: inertia=266,353
# k=5: inertia=241,184
# k=6: inertia=225,861
# k=7: inertia=210,799
# k=8: inertia=198,322
# k=9: inertia=187,524
# k=10: inertia=180,261

# %% [markdown]
# ## 10. Running K-Means (k=5)
#
# Running the final model with k=5 and assigning a cluster to every song.

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(features_scaled)

print("Songs per cluster:")
print(df['cluster'].value_counts().sort_index())

# average feature values per cluster to understand what each cluster represents
cluster_profile = df.groupby('cluster')[MOOD_FEATURES].mean().round(3)
print("Cluster profiles (average feature values):")
print(cluster_profile)
# Out:
# Songs per cluster:
# cluster
# 0    19797
# 1    19811
# 2    15472
# 3     7210
# 4    27450
# Name: count, dtype: int64
# Cluster profiles (average feature values):
#          valence  energy  danceability  acousticness    tempo  loudness
# cluster
# 0          0.279   0.762         0.527         0.088  110.777    -6.669
# 1          0.430   0.399         0.562         0.701  115.078   -10.722
# 2          0.451   0.819         0.464         0.114  162.554    -5.488
# 3          0.161   0.164         0.308         0.861   99.702   -20.919
# 4          0.727   0.732         0.710         0.214  118.279    -6.649

# %% [markdown]
# ## 11. Naming the Clusters
#
# Looking at the cluster profiles I can figure out what mood each one represents:
#
# - **Cluster 0**: low valence + high energy → sounds angry/intense
# - **Cluster 1**: medium valence + low energy + very acoustic → sounds sad/mellow
# - **Cluster 2**: high energy + highest tempo → clearly energetic
# - **Cluster 3**: very low energy + very acoustic → calm and quiet
# - **Cluster 4**: highest valence + high energy → happy and upbeat

# %%
MOOD_NAMES = {
    0: 'Angry',
    1: 'Sad',
    2: 'Energetic',
    3: 'Calm',
    4: 'Happy'
}

df['mood'] = df['cluster'].map(MOOD_NAMES)

# define these here so they're available for all cells below
moods = ['Happy', 'Sad', 'Energetic', 'Calm', 'Angry']
mood_emojis = {'Happy':'😊', 'Sad':'😢', 'Energetic':'⚡', 'Calm':'😌', 'Angry':'😤'}
mood_colors = {'Happy':'#FFD700', 'Sad':'#4169E1', 'Energetic':'#FF4500', 'Calm':'#32CD32', 'Angry':'#DC143C'}

print("Songs per mood:")
print(df['mood'].value_counts())
# Out:
# Songs per mood:
# mood
# Happy        27450
# Sad          19811
# Angry        19797
# Energetic    15472
# Calm          7210
# Name: count, dtype: int64

# %% [markdown]
# ## 12. Checking Sample Songs Per Mood
#
# Quick sanity check — do the songs actually match their assigned mood?

# %%
# mood_emojis already defined above
for mood in ['Happy', 'Sad', 'Energetic', 'Calm', 'Angry']:
    sample = df[df['mood']==mood][['track_name','artists','valence','energy']].head(3)
    print(f"\n{mood_emojis[mood]} {mood}:")
    print(sample.to_string(index=False))
# Out:
# 😊 Happy:
#           track_name                   artists  valence  energy
#               Comedy               Gen Hoshino    0.715   0.461
# Days I Will Remember              Tyrone Wells    0.666   0.481
#                Lucky Jason Mraz;Colbie Caillat    0.669   0.414
#
# 😢 Sad:
#    track_name                              artists  valence  energy
#       Hold On                     Chord Overstreet   0.1670   0.443
# Say Something A Great Big World;Christina Aguilera   0.0765   0.147
#     I'm Yours                           Jason Mraz   0.7120   0.444
#
# ⚡ Energetic:
#                                  track_name               artists  valence  energy
# All I Want For Christmas Is A Real Good Tan      Chord Overstreet    0.564   0.455
#                                   The Haves          Eddie Vedder    0.326   0.519
#                      You and Me on the Rock Brandi Carlile;Lucius    0.725   0.686
#
# 😌 Calm:
# ...

# %% [markdown]
# ## 13. Most Popular Songs Per Mood

# %%
for mood in ['Happy', 'Sad', 'Energetic', 'Calm', 'Angry']:
    top = df[df['mood']==mood].nlargest(3, 'popularity')[
        ['track_name', 'artists', 'popularity']
    ]
    print(f"\n{mood_emojis[mood]} Top {mood} songs:")
    for _, row in top.iterrows():
        print(f"  {row['track_name'][:40]} - {row['artists'][:25]} (pop={row['popularity']})")
# Out:
# 😊 Top Happy songs:
#   Quevedo: Bzrp Music Sessions, Vol. 52 - Bizarrap;Quevedo (pop=99)
#   La Bachata - Manuel Turizo (pop=98)
#   Me Porto Bonito - Bad Bunny;Chencho Corleon (pop=97)
#
# 😢 Top Sad songs:
#   Glimpse of Us - Joji (pop=94)
#   Another Love - Tom Odell (pop=93)
#   PROVENZA - KAROL G (pop=93)
#
# ⚡ Top Energetic songs:
#   As It Was - Harry Styles (pop=95)
#   As It Was - Harry Styles (pop=92)
#   Jimmy Cooks (feat. 21 Savage) - Drake;21 Savage (pop=91)
#
# 😌 Top Calm songs:
#   Clean White Noise - Loopable with no fad - White Noise Baby Sleep;Wh (pop=85)
#   Lights Are On - Tom Rosenthal (pop=81)
#   rises the moon - Liana Flores (pop=81)
#
# 😤 Top Angry songs:
#   Unholy (feat. Kim Petras) - Sam Smith;Kim Petras (pop=100)
#   I'm Good (Blue) - David Guetta;Bebe Rexha (pop=98)
#   Tití Me Preguntó - Bad Bunny (pop=97)

# %% [markdown]
# ## 14. Mood Audio Profiles
#
# Bar charts showing the average audio characteristics of each mood — this makes it easy to see what makes them different.

# %%
# mood_emojis, moods, mood_colors already defined above
features_to_plot = ['valence', 'energy', 'danceability', 'acousticness']

fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Average Audio Profile Per Mood', fontsize=14, fontweight='bold')

for i, mood in enumerate(moods):
    mood_data = df[df['mood']==mood][features_to_plot].mean()
    bars = axes[i].bar(features_to_plot, mood_data,
                       color=mood_colors[mood], alpha=0.85, edgecolor='white')
    axes[i].set_title(f"{mood_emojis[mood]} {mood}", fontweight='bold')
    axes[i].set_ylim(0, 1)
    axes[i].set_xticklabels(features_to_plot, rotation=35, ha='right', fontsize=9)
    axes[i].set_ylabel('avg value')
    for bar, val in zip(bars, mood_data):
        axes[i].text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.02,
                    f'{val:.2f}', ha='center', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.savefig('mood_profiles.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 15. Visualising Clusters (PCA)
#
# K-Means worked in 6 dimensions so I can't directly see the clusters. PCA reduces this to 2 dimensions so I can plot them and see how well separated the moods are.

# %%
pca = PCA(n_components=2, random_state=42)
coords_2d = pca.fit_transform(features_scaled)

# use a random sample of 4000 points so the plot isn't too crowded
idx = np.random.choice(len(coords_2d), 4000, replace=False)

plt.figure(figsize=(10, 7))
for mood in moods:
    mask = df['mood'].iloc[idx] == mood
    plt.scatter(coords_2d[idx][mask, 0], coords_2d[idx][mask, 1],
                c=mood_colors[mood], label=f"{mood_emojis[mood]} {mood}",
                alpha=0.45, s=12)

plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)')
plt.title('Mood Clusters in 2D (PCA) — 4000 random songs', fontweight='bold')
plt.legend(markerscale=3)
plt.grid(True, alpha=0.2)
plt.tight_layout()
plt.savefig('pca_clusters.png', dpi=120, bbox_inches='tight')
plt.show()

print(f"Variance explained by 2 components: {sum(pca.explained_variance_ratio_)*100:.1f}%")
# Out:
# Variance explained by 2 components: 67.1%

# %% [markdown]
# ## 16. Saving Everything
#
# Saving the labelled dataset, the scaler, and the K-Means model so the Flask app can load them directly without re-running this notebook.

# %%
os.makedirs('cache', exist_ok=True)

df.to_csv('cache/songs_with_moods.csv', index=False)
print(f"saved {len(df)} songs to cache/songs_with_moods.csv")

with open('cache/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("saved scaler to cache/scaler.pkl")

with open('cache/kmeans.pkl', 'wb') as f:
    pickle.dump(kmeans, f)
print("saved kmeans model to cache/kmeans.pkl")

with open('cache/mood_names.pkl', 'wb') as f:
    pickle.dump(MOOD_NAMES, f)
print("saved mood names to cache/mood_names.pkl")

print("Files in cache/:")
for fname in sorted(os.listdir('cache')):
    kb = os.path.getsize('cache/' + fname) / 1024
    print(f"  {fname}: {kb:.1f} KB")
# Out:
# saved 89740 songs to cache/songs_with_moods.csv
# saved scaler to cache/scaler.pkl
# saved kmeans model to cache/kmeans.pkl
# saved mood names to cache/mood_names.pkl
# Files in cache/:
#   kmeans.pkl: 351.4 KB
#   mood_names.pkl: 0.1 KB
#   scaler.pkl: 0.7 KB
#   songs_with_moods.csv: 15794.1 KB

# %% [markdown]
# ## 17. Summary
#
# ### What I did
#
# 1. Loaded the Spotify Tracks Dataset — 114,000 songs
# 2. Cleaned it — removed duplicates and missing rows, ended up with ~89,740 songs
# 3. Picked 6 audio features that relate to mood: valence, energy, danceability, acousticness, tempo, loudness
# 4. Scaled the features so K-Means treats all of them equally
# 5. Used the Elbow Method to confirm k=5 is a good number of clusters
# 6. Ran K-Means and assigned a mood label to every song
# 7. Named each cluster by looking at its average feature values
# 8. Verified the results by checking sample songs and the most popular songs per mood
#
# ### What I learned
#
# The most useful features turned out to be valence and energy — together they separate most moods pretty clearly. Acousticness was also important for separating Calm and Sad from the other three. Songs with high valence and high energy are almost always upbeat, while very low energy songs tend to feel calm or sad.
#
# ### Limitation
#
# The mood labels are based on audio features, not how people actually feel when they hear a song. Two songs can have very similar feature values but feel completely different to a listener. This is a known limitation of this kind of approach — you'd need human-labelled data to get around it.
#
# ### Next
#
# The Flask app (app.py) will load these saved files and use them to generate playlists based on mood selection.
